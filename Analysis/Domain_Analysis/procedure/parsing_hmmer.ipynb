# %% [markdown]
# ## HMMER file parsing and results counting
# This code will parse and count the number of HMMER search results generated from the previous step and output it to a table.

# %%
#!/usr/bin/python
from collections import defaultdict
import pandas as pd
from os.path import exists, join
import pdb
import os
import re

# %% [markdown]
# # Import files and setup directories for parsing files

# %%
input_hmmer_dir = "../output/hmmer_txt_output/"
input_dir = "../input/"

output_file = "hmmer_count_results_cnidarian2.tsv"
output_dir = "../output/"
output_filepath = join(output_dir,output_file)

required = [input_dir,input_hmmer_dir,output_dir]

for r in required:
    if not exists(r):
        raise FileNotFoundError(f"The specified hmmer file {r} does not seem to be in the specified path.")
    print(f"Confirmed that required file or directory {r} exists.")
# Out:
# Confirmed that required file or directory ../input/ exists.
# Confirmed that required file or directory ../output/hmmer_txt_output/ exists.
# Confirmed that required file or directory ../output/ exists.

# %% [markdown]
# # Prepare a output file so that data generated from the loop in the next step can be written to it.
# The column names in the file are: Species File, Domain, Count, and Unique Count. The count is the total number of hits Hmmer found wile unique count only takes into account different hits (ie no duplicate hits).

# %%
#prepare the output file for the loop by adding column names
column_names = ["Species_File", "Domain", "Count", "Unique_Count_Isoform", "Unique_count_Sequence"]
with open(output_filepath, 'w') as output:
    output.write("%s" % "\t".join(column_names)+"\n")

# %% [markdown]
# ## Loop to count the number of unique outputs generated by HMMER
# Convert HMMER text results into a pandas data frame and then count the results.
# Note: HMMER uses space delimination

# %%
for results_file in os.listdir(input_hmmer_dir):
    if not results_file.endswith(".txt"):
        continue
    #convert the HMMER output to a pandas dataframe (separated by spaces)
    hmmer_results = pd.read_csv((input_hmmer_dir + results_file),sep = "\s+", \
                                comment = "#", index_col = False,\
            names=["target_name", "accession description", "query name", "accession",\
            "full sequence E-value", "full sequence score", "full sequence bias",\
            "best 1 domain E-value", "best domain score", "best domain bias",\
            "domain number estimation exp", "domain number estimation reg",\
            "domain number estimation clu", "domain number estimation ov",\
            "domain number estimation env", "domain number estimation dom",\
            "domain number estimation rep", "domain number estimation inc",\
            "description of target"])
    
    #select e value columns. Count the number of total and unique ids in the column
    #if no values are present in the file (ie no matches were found) assign 0s.
    hit_indicies = hmmer_results["full sequence E-value"]<.1
    
    if not True in list(hit_indicies):
        print("No hits. Manualy assigning 0s")
        hmmer_unique_target_isoform = 0
        unique_target_id_count = 0
        hmmer_total_id = 0
    else:
        hmmer_select_df = hmmer_results[hit_indicies]
    
        #count the total number of hits by isolating the first value from the shape output
        hmmer_total_id = hmmer_select_df.shape[0]
    
        #count the uniques id hits including isoforms
        hmmer_unique_target_isoform = hmmer_select_df.target_name.nunique()
    
        #count unique target names only not number of isoforms
        unique_target_id = hmmer_select_df.target_name.str.split('.p').str[0]
        unique_target_id_count = unique_target_id.nunique()
    
    # extract domain used from file name
    results_domain_used = results_file.split("_")[-5]
    
    #extract only the species name from the output file name
    species_name = results_file[:results_file.index('longest')]
    
    #print what is being analyzed in the same stile that it will be put in the table
    print(f"Writing the output file: {species_name}, {results_domain_used},\
    {hmmer_total_id}, {hmmer_unique_target_isoform}, {unique_target_id_count}")
    
    #write the results to a table 
    with open(output_filepath, 'a') as output:
        output_field = [(species_name), (results_domain_used), (hmmer_total_id),\
                        (hmmer_unique_target_isoform), (unique_target_id_count)]
        output.write("\t".join(map(str, output_field))+"\n")
# Out:
# Writing the output file: M_capitata_, PF00560,    91, 91, 78
# Writing the output file: P_verrucosa_, PF13855,    298, 298, 221
# Writing the output file: M_efflorescens_, PF01582,    35, 35, 19
# Writing the output file: Fungia_, PF00560,    79, 79, 56
# Writing the output file: M_capitata_, PF00047,    415, 415, 225
# No hits. Manualy assigning 0s
# Writing the output file: O_faveolata_, PF18837,    0, 0, 0
# Writing the output file: P_damicornis_, PF13516,    107, 107, 75
# Writing the output file: P_damicornis_, PF01582,    24, 24, 14
# Writing the output file: A_hyactintus_, PF12799,    287, 287, 108
# Writing the output file: M_capitata_, PF13855,    191, 191, 158
# Writing the output file: M_efflorescens_, PF13895,    511, 511, 170
# Writing the output file: Aiptasia_, PF00047,    455, 455, 133
# Writing the output file: A_hyactintus_, PF18837,    3, 3, 3
# Writing the output file: Fungia_, PF01582,    32, 32, 17
# Writing the output file: A_cytherea_, PF00560,    138, 138, 75
# Writing the output file: P_verrucosa_, PF01582,    28, 28, 17
# Writing the output file: A_hyactintus_, PF13895,    574, 574, 135
# Writing the output file: P_rus_, PF00047,    454, 454, 222
# Writing the output file: P_damicornis_, PF12799,    118, 118, 87
# Writing the output file: A_hyactintus_, PF00047,    565, 565, 138
# Writing the output file: A_aurita_, PF13895,    159, 159, 69
# Writing the output file: Aiptasia_, PF13927,    459, 459, 131
# Writing the output file: A_hyactintus_, PF18452,    195, 195, 79
# Writing the output file: Aiptasia_, PF12799,    155, 155, 119
# Writing the output file: S_pistillata_, PF00047,    592, 592, 220
# Writing the output file: M_efflorescens_, PF18837,    1, 1, 1
# Writing the output file: P_lutea_, PF13895,    664, 664, 182
# Writing the output file: A_aurita_, PF12799,    56, 56, 43
# Writing the output file: P_rus_, PF13519,    188, 188, 61
# Writing the output file: A_cytherea_, PF18837,    5, 5, 5
# Writing the output file: Fungia_, PF00047,    622, 622, 214
# Writing the output file: Aiptasia_, PF01582,    7, 7, 6
# Writing the output file: P_verrucosa_, PF00560,    119, 119, 95
# Writing the output file: Aiptasia_, PF18452,    198, 198, 72
# Writing the output file: P_lutea_, PF07725,    1, 1, 1
# No hits. Manualy assigning 0s
# Writing the output file: Aiptasia_, PF07725,    0, 0, 0
# Writing the output file: P_damicornis_, PF18452,    124, 124, 55
# Writing the output file: P_rus_, PF13516,    135, 135, 111
# Writing the output file: P_lutea_, PF13516,    203, 203, 91
# Writing the output file: Xen_, PF12799,    99, 99, 12
# No hits. Manualy assigning 0s
# Writing the output file: S_pistillata_, PF07725,    0, 0, 0
# Writing the output file: P_verrucosa_, PF13927,    752, 752, 269
# Writing the output file: O_faveolata_, PF18452,    170, 170, 66
# No hits. Manualy assigning 0s
# Writing the output file: O_faveolata_, PF07725,    0, 0, 0
# Writing the output file: P_rus_, PF01582,    29, 29, 21
# Writing the output file: G_fascicularis_, PF13855,    111, 111, 92
# Writing the output file: P_lutea_, PF18837,    1, 1, 1
# Writing the output file: M_capitata_, PF13516,    183, 183, 148
# Writing the output file: P_verrucosa_, PF13895,    736, 736, 259
# Writing the output file: A_cytherea_, PF18452,    199, 199, 80
# Writing the output file: P_damicornis_, PF13855,    120, 120, 87
# Writing the output file: M_capitata_, PF13927,    421, 421, 225
# No hits. Manualy assigning 0s
# Writing the output file: P_verrucosa_, PF07725,    0, 0, 0
# Writing the output file: O_faveolata_, PF13519,    278, 278, 56
# Writing the output file: A_cytherea_, PF13519,    212, 212, 54
# Writing the output file: P_verrucosa_, PF18452,    283, 283, 121
# No hits. Manualy assigning 0s
# Writing the output file: P_damicornis_, PF18837,    0, 0, 0
# Writing the output file: P_rus_, PF13855,    178, 178, 150
# Writing the output file: A_cytherea_, PF13855,    318, 318, 135
# Writing the output file: O_faveolata_, PF13895,    452, 452, 123
# Writing the output file: S_pistillata_, PF12799,    212, 212, 142
# Writing the output file: A_hyactintus_, PF13519,    216, 216, 44
# Writing the output file: Xen_, PF13895,    211, 211, 12
# Writing the output file: G_fascicularis_, PF18452,    139, 139, 79
# Writing the output file: P_lutea_, PF18452,    267, 267, 95
# Writing the output file: A_cytherea_, PF13516,    346, 346, 133
# Writing the output file: Fungia_, PF13519,    298, 298, 104
# No hits. Manualy assigning 0s
# Writing the output file: Fungia_, PF07725,    0, 0, 0
# Writing the output file: Xen_, PF01582,    7, 7, 5
# Writing the output file: O_faveolata_, PF12799,    120, 120, 70
# No hits. Manualy assigning 0s
# Writing the output file: A_cytherea_, PF07725,    0, 0, 0
# Writing the output file: A_hyactintus_, PF13855,    309, 309, 110
# Writing the output file: A_aurita_, PF13519,    72, 72, 32
# Writing the output file: G_fascicularis_, PF13927,    363, 363, 169
# Writing the output file: M_capitata_, PF13895,    433, 433, 235
# Writing the output file: A_aurita_, PF18452,    65, 65, 37
# Writing the output file: Aiptasia_, PF13519,    178, 178, 51
# Writing the output file: A_hyactintus_, PF00560,    142, 142, 58
# Writing the output file: A_hyactintus_, PF01582,    37, 37, 16
# Writing the output file: P_rus_, PF13927,    463, 463, 226
# Writing the output file: A_aurita_, PF13516,    30, 30, 28
# Writing the output file: O_faveolata_, PF01582,    27, 27, 15
# Writing the output file: S_pistillata_, PF13855,    243, 243, 159
# Writing the output file: Xen_, PF00047,    213, 213, 11
# Writing the output file: A_aurita_, PF00047,    157, 157, 69
# Writing the output file: P_rus_, PF13895,    465, 465, 229
# Writing the output file: Aiptasia_, PF13855,    148, 148, 110
# Writing the output file: A_aurita_, PF13855,    61, 61, 47
# Writing the output file: S_pistillata_, PF13516,    219, 219, 133
# Writing the output file: A_cytherea_, PF00047,    565, 565, 159
# Writing the output file: P_rus_, PF18452,    200, 200, 102
# Writing the output file: P_lutea_, PF13519,    256, 256, 65
# Writing the output file: A_cytherea_, PF01582,    33, 33, 17
# Writing the output file: P_lutea_, PF00047,    665, 665, 190
# Writing the output file: P_rus_, PF18837,    2, 2, 2
# Writing the output file: M_efflorescens_, PF00560,    87, 87, 54
# Writing the output file: S_pistillata_, PF00560,    72, 72, 48
# Writing the output file: S_pistillata_, PF18452,    185, 185, 91
# Writing the output file: Fungia_, PF13855,    209, 209, 139
# Writing the output file: M_efflorescens_, PF00047,    487, 487, 166
# No hits. Manualy assigning 0s
# Writing the output file: M_efflorescens_, PF07725,    0, 0, 0
# Writing the output file: Aiptasia_, PF13895,    445, 445, 129
# No hits. Manualy assigning 0s
# Writing the output file: A_hyactintus_, PF07725,    0, 0, 0
# Writing the output file: S_pistillata_, PF13895,    637, 637, 242
# Writing the output file: P_verrucosa_, PF13516,    314, 314, 217
# Writing the output file: A_cytherea_, PF13895,    579, 579, 157
# Writing the output file: A_aurita_, PF00560,    23, 23, 20
# Writing the output file: P_lutea_, PF13927,    680, 680, 188
# Writing the output file: P_damicornis_, PF13927,    354, 354, 123
# No hits. Manualy assigning 0s
# Writing the output file: Fungia_, PF18837,    0, 0, 0
# No hits. Manualy assigning 0s
# Writing the output file: S_pistillata_, PF18837,    0, 0, 0
# Writing the output file: P_verrucosa_, PF00047,    712, 712, 252
# Writing the output file: Aiptasia_, PF00560,    31, 31, 27
# Writing the output file: Fungia_, PF13516,    176, 176, 107
# Writing the output file: M_capitata_, PF01582,    27, 27, 18
# Writing the output file: A_hyactintus_, PF13516,    342, 342, 103
# Writing the output file: M_efflorescens_, PF18452,    137, 137, 72
# Writing the output file: P_lutea_, PF13855,    233, 233, 125
# Writing the output file: P_rus_, PF12799,    153, 153, 134
# Writing the output file: A_cytherea_, PF12799,    289, 289, 126
# Writing the output file: P_verrucosa_, PF13519,    288, 288, 83
# Writing the output file: P_lutea_, PF01582,    36, 36, 24
# Writing the output file: M_efflorescens_, PF13519,    204, 204, 65
# Writing the output file: Xen_, PF18837,    3, 3, 2
# Writing the output file: A_cytherea_, PF13927,    581, 581, 161
# Writing the output file: O_faveolata_, PF13855,    134, 134, 72
# Writing the output file: A_aurita_, PF13927,    167, 167, 72
# No hits. Manualy assigning 0s
# Writing the output file: Aiptasia_, PF18837,    0, 0, 0
# Writing the output file: Fungia_, PF13895,    632, 632, 222
# Writing the output file: P_verrucosa_, PF18837,    1, 1, 1
# Writing the output file: Fungia_, PF13927,    632, 632, 219
# Writing the output file: G_fascicularis_, PF13516,    109, 109, 90
# Writing the output file: M_efflorescens_, PF13927,    513, 513, 169
# Writing the output file: M_efflorescens_, PF12799,    204, 204, 122
# Writing the output file: P_damicornis_, PF13519,    227, 227, 54
# Writing the output file: S_pistillata_, PF13927,    636, 636, 244
# No hits. Manualy assigning 0s
# Writing the output file: P_rus_, PF07725,    0, 0, 0
# No hits. Manualy assigning 0s
# Writing the output file: A_aurita_, PF07725,    0, 0, 0
# Writing the output file: M_efflorescens_, PF13516,    211, 211, 111
# Writing the output file: P_verrucosa_, PF12799,    292, 292, 221
# Writing the output file: M_efflorescens_, PF13855,    200, 200, 118
# No hits. Manualy assigning 0s
# Writing the output file: G_fascicularis_, PF18837,    0, 0, 0
# No hits. Manualy assigning 0s
# Writing the output file: M_capitata_, PF07725,    0, 0, 0
# Writing the output file: P_lutea_, PF12799,    206, 206, 116
# Writing the output file: S_pistillata_, PF01582,    23, 23, 16
# Writing the output file: O_faveolata_, PF13516,    89, 89, 55
# Writing the output file: A_aurita_, PF01582,    12, 12, 12
# Writing the output file: P_damicornis_, PF00560,    45, 45, 36
# Writing the output file: A_hyactintus_, PF13927,    584, 584, 139
# Writing the output file: P_rus_, PF00560,    81, 81, 70
# Writing the output file: S_pistillata_, PF13519,    222, 222, 67
# Writing the output file: Xen_, PF13516,    91, 91, 10
# Writing the output file: Xen_, PF18452,    64, 64, 10
# Writing the output file: G_fascicularis_, PF13519,    213, 213, 65
# Writing the output file: G_fascicularis_, PF12799,    106, 106, 87
# Writing the output file: P_lutea_, PF00560,    110, 110, 55
# Writing the output file: O_faveolata_, PF00560,    53, 53, 33
# Writing the output file: Xen_, PF13855,    103, 103, 14
# Writing the output file: P_damicornis_, PF13895,    346, 346, 121
# Writing the output file: G_fascicularis_, PF01582,    19, 19, 15
# Writing the output file: Fungia_, PF12799,    197, 197, 130
# Writing the output file: Xen_, PF00560,    18, 18, 10
# Writing the output file: M_capitata_, PF12799,    185, 185, 154
# No hits. Manualy assigning 0s
# Writing the output file: G_fascicularis_, PF07725,    0, 0, 0
# Writing the output file: Xen_, PF07725,    6, 6, 3
# Writing the output file: Fungia_, PF18452,    246, 246, 109
# Writing the output file: Xen_, PF13927,    222, 222, 13
# No hits. Manualy assigning 0s
# Writing the output file: P_damicornis_, PF07725,    0, 0, 0
# Writing the output file: G_fascicularis_, PF13895,    357, 357, 170
# Writing the output file: G_fascicularis_, PF00560,    46, 46, 39
# Writing the output file: G_fascicularis_, PF00047,    343, 343, 163
# Writing the output file: Aiptasia_, PF13516,    140, 140, 101
# Writing the output file: M_capitata_, PF13519,    199, 199, 74
# Writing the output file: O_faveolata_, PF00047,    453, 453, 127
# No hits. Manualy assigning 0s
# Writing the output file: A_aurita_, PF18837,    0, 0, 0
# Writing the output file: O_faveolata_, PF13927,    465, 465, 128
# Writing the output file: Xen_, PF13519,    115, 115, 11
# Writing the output file: M_capitata_, PF18452,    128, 128, 86
# No hits. Manualy assigning 0s
# Writing the output file: M_capitata_, PF18837,    0, 0, 0
# Writing the output file: P_damicornis_, PF00047,    341, 341, 115
